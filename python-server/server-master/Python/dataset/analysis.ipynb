# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
table = pd.read_csv("trial_lookup_filtering_coeff.csv")

# %%
table.describe()
# Out:
#        Unnamed: 0      NumLeft  FieldAreaLeft  ItemSurfaceAreaLeft  \
# count  4096.00000  4096.000000    4096.000000          4096.000000
# mean   2047.50000    19.406250   20381.943750           136.581875
# std    1182.55768    19.473083   10646.535116            89.871965
# min       0.00000     1.000000    5625.000000            19.240000
# 25%    1023.75000     9.000000   11302.082500            59.060000
# 50%    2047.50000    13.000000   18923.610000           120.420000
# 75%    3071.25000    21.000000   28489.585000           203.330000
# max    4095.00000   112.000000   40000.000000           307.790000
#
#           NumRight  FieldAreaRight  ItemSurfaceAreaRight    Ratio L/R  \
# count  4096.000000     4096.000000           4096.000000  4096.000000
# mean     19.406250    20381.943750            136.581875     1.787000
# std      19.473083    10646.535116             89.871965     2.603246
# min       1.000000     5625.000000             19.240000     0.030000
# 25%       9.000000    11302.082500             59.060000     0.560000
# 50%      13.000000    18923.610000            120.420000     1.000000
# 75%      21.000000    28489.585000            203.330000     1.800000
# max     112.000000    40000.000000            307.790000    29.000000
#
#            LogRatio  Log - Normalized  Difficulty Coefficient  \
# count  4.096000e+03       4096.000000             4096.000000
# mean   4.336809e-18          0.230098                0.769902
# std    4.609645e-01          0.215049                0.215049
# min   -1.460000e+00          0.000000                0.000000
# 25%   -2.600000e-01          0.050000                0.650000
# 50%    0.000000e+00          0.170000                0.830000
# 75%    2.600000e-01          0.350000                0.950000
# max    1.460000e+00          1.000000                1.000000
#
#        Diff_coeff_filtering
# count           4096.000000
# mean               0.287451
# std                0.251325
# min               -0.027765
# 25%                0.032306
# 50%                0.297674
# 75%                0.470932
# max                1.000000

# %%
margin = 0.009
diff = 0.2

low_filter = table[table["Diff_coeff_filtering"] > max(0, diff-margin)]
high_filter =low_filter[low_filter["Diff_coeff_filtering"] < min(diff+margin, 0.99)]

# %%
high_filter
# Out:
#       Unnamed: 0  NumLeft  FieldAreaLeft  ItemSurfaceAreaLeft  NumRight  \
# 191          191       69       27777.78                19.24       112
# 251          251      112       40000.00                19.24        69
# 261          261        9        5625.00                27.70        29
# 336          336       29       13611.11                27.70         9
# 536          536        9        6944.44                37.70        37
# ...          ...      ...            ...                  ...       ...
# 3881        3881        1        8402.78               307.79         9
# 3963        3963        5       17777.78               307.79         9
# 3986        3986        9       22500.00               307.79         1
# 4023        4023        9       27777.78               307.79         5
# 4065        4065        9       36736.11               307.79         1
#
#       FieldAreaRight  ItemSurfaceAreaRight  Ratio L/R  LogRatio  \
# 191         40000.00                 19.24       0.62     -0.21
# 251         27777.78                 19.24       1.62      0.21
# 261         13611.11                 27.70       0.31     -0.51
# 336          5625.00                 27.70       3.22      0.51
# 536         20069.44                 37.70       0.24     -0.61
# ...              ...                   ...        ...       ...
# 3881        22500.00                307.79       0.11     -0.95
# 3963        27777.78                307.79       0.56     -0.26
# 3986         8402.78                307.79       9.00      0.95
# 4023        17777.78                307.79       1.80      0.26
# 4065         6944.44                307.79       9.00      0.95
#
#       Log - Normalized  Difficulty Coefficient  Diff_coeff_filtering
# 191               0.14                    0.86              0.201698
# 251               0.14                    0.86              0.201698
# 261               0.35                    0.65              0.204188
# 336               0.35                    0.65              0.204188
# 536               0.42                    0.58              0.199561
# ...                ...                     ...                   ...
# 3881              0.65                    0.35              0.206079
# 3963              0.17                    0.83              0.208293
# 3986              0.65                    0.35              0.206079
# 4023              0.17                    0.83              0.208293
# 4065              0.65                    0.35              0.207159
#
# [68 rows x 12 columns]
